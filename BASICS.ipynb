# %%
#show image
import cv2
image=cv2.imread("1.jpg")
cv2.imshow("hi",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#print image as an array
import numpy as np
print (image.shape)
# Out:
# (768L, 1024L, 3L)

# %%
#shape of image
print ("Height of Image:",int(image.shape[0]))
print ("length of Image:",int(image.shape[1]))
print ("width of Image:",int(image.shape[2]))
# Out:
# ('Height of Image:', 768)
# ('length of Image:', 1024)
# ('width of Image:', 3)

# %%
#save images
cv2.imwrite("my.jpg",image)
cv2.imwrite("my.png",image)
# Out:
# True

# %%
#playing with RGB
B,G,R = cv2.split(image)
print(B)
cv2.imshow("A",B)
cv2.imshow("B",G)
cv2.imshow("C",R+40)
cv2.waitKey(0)
cv2.destroyAllWindows()

merged=cv2.merge([B,G,R])
cv2.imshow("merged",merged)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[217 217 217 ... 225 225 226]
#  [216 216 216 ... 225 225 226]
#  [217 217 216 ... 225 225 226]
#  ...
#  [ 96  96  96 ... 142 139 135]
#  [ 96  95  96 ... 147 143 143]
#  [ 96  95  95 ... 154 153 157]]

# %%
#show RGB Split seperately
import cv2
import numpy as np
image=cv2.imread("1.jpg")
#B,G,R=cv2.split(image)
zeros=np.zeros(image.shape[:2],dtype="uint8")
cv2.imshow("R",cv2.merge([zeros,zeros,R+100]))
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imshow("G",cv2.merge([zeros,G,zeros]))
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imshow("B",cv2.merge([B,zeros,zeros]))
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#histogram
import cv2
from matplotlib import pyplot as plt
image = cv2.imread("2.jpg")
cv2.imshow("2.jpg",image)
cv2.waitKey(0)
cv2.destroyAllWindows()
histogram=cv2.calcHist([image],[0],None,[200],[0,200])
plt.hist(image.ravel(),256,[0,256])
plt.show()
color=("b","g","r")
for i , col in enumerate(color):
    histogram2=cv2.calcHist([image],[i],None,[255],[0,255])
    plt.plot(histogram2, color=col)
    plt.xlim([0,255])
plt.show()

# %%
#creating Blank image
import cv2
import numpy as np
myimg=np.zeros((512,512,3),np.uint8)
myimg_bw=np.zeros((512,512),np.uint8)
cv2.imshow("1",myimg)
cv2.imshow("2",myimg_bw)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#draw line
import cv2
import numpy as np
image=np.zeros((512,512,3))
cv2.line(image,(0,0),(255,255),(100,100,100),5)
cv2.imshow("hi",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#draw rectangle
import cv2
import numpy as np
image=np.zeros((512,512,3),np.uint8)
cv2.rectangle(image,(300,200),(0,0),(127,50,127),-50)
cv2.imshow("rect" ,image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#draw Circle
import cv2
import numpy as np
image=np.zeros((1024,1024,3),np.uint8)
cv2.circle(image,(255,255),50,(10000,100,100),5)
cv2.imwrite("circle.jpg",image)
cv2.imshow("circle",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#draw polygon
import cv2
import numpy as np
image=np.zeros((512,512,3),np.uint8)
pts=np.array([[10,50],[400,50],[90,200],[50,500],[0,0]], np.int32)

cv2.polylines(image,[pts],False,(0,0,255),3)
cv2.imshow("hi",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#put text on image
import cv2
import numpy as np
image=np.zeros((512,512,3),np.uint8)
cv2.putText(image,"P@@",(100,100),cv2.FONT_HERSHEY_SIMPLEX,5,(100,120,3),3)
cv2.imshow("hi",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#image shift translation
import cv2
import numpy as np
image=cv2.imread("1.jpg")
h,w=image.shape[:2]
qh,qw=h/4,w/4
t=np.float32([[1,0,qw],[0,1,qh]])
print(t)
img=cv2.warpAffine(image,t,(w,h))
cv2.imshow("translated",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[  1.   0. 256.]
#  [  0.   1. 192.]]

# %%
#rotate the image
import cv2
import numpy as np
image=cv2.imread("2.jpg",0)
h,w=image.shape[:2]
qh,qw=h/2,w/2
r=cv2.getRotationMatrix2D((qw,qh),90,1)
print(r)
img=cv2.warpAffine(image,r,(w,h))
cv2.imshow("translated",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[ 6.123234e-17  1.000000e+00  1.420000e+02]
#  [-1.000000e+00  6.123234e-17  4.980000e+02]]

# %%
#scalling image
import cv2
import numpy as np
image=cv2.imread("2.jpg",0)
h,w=image.shape[:2]
qh,qw=h/2,w/2
r=cv2.transpose(image)
print(r)

cv2.imshow("translated",r)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[  4  12  23 ... 100  93  98]
#  [  4  11  19 ... 171 144 111]
#  [  5   8  14 ... 219 182 121]
#  ...
#  [  4   4   4 ...  85  92  96]
#  [  4   4   4 ... 101  94  91]
#  [  4   4   4 ... 101  82  68]]

# %%
#resize image
import cv2
import numpy as np
image=cv2.imread("2.jpg")
scimg=cv2.resize(image,None,fx=0.75,fy=2)
scimg1=cv2.resize(image, None, fx=3, fy=3, interpolation = cv2.INTER_CUBIC)
scimg2=cv2.resize(image,(9000,400),interpolation = cv2.INTER_AREA)
cv2.imshow("hello",scimg)
cv2.waitKey(0)
cv2.imshow("hello",scimg1)
cv2.waitKey(0)
cv2.imshow("hello",scimg2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#scalling
import cv2
import numpy as np
cv2.imread("1.jpg")
small=cv2.pyrDown(image)
large=cv2.pyrUp(small)
cv2.imshow("small",small)
cv2.imshow("large",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#cropping image
import cv2
import numpy as np
h,w=image.shape[:2]
image=cv2.imread("1.jpg")
r1,c1=int(h*.25),int(w*.25)
r2,c2=int(h*.75),int(w*.75)
cropped=image[r1:r2,c1:c2]
cv2.imshow("hello",image)
cv2.waitKey(0)
cv2.imshow("hello hi",cropped)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#bright and Dark
import cv2
import numpy as np
image=cv2.imread("1.jpg")

m=np.ones(image.shape,dtype="uint8")*175
add=cv2.add(image,m)
substract=cv2.subtract(image,m)
cv2.imshow("bright",add)
cv2.waitKey(0)
cv2.imshow("dark",substract)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#draw shapes
import cv2
import numpy as np
el=np.zeros((300,300),np.uint8)
cv2.ellipse(el,(150,150),(150,150),30,0,180,255,-1)
cv2.imshow("el",el)
cv2.waitKey(0)
rc=np.zeros((300,300),np.uint8)
cv2.rectangle(rc,(0,0),(128,128),255,-1)
cv2.imshow("rc",rc)
cv2.waitKey(0)
orop=cv2.bitwise_or(el,rc)
cv2.imshow("or",orop)
cv2.waitKey(0)
andop=cv2.bitwise_and(el,rc)
cv2.imshow("and",andop)
cv2.waitKey(0)
xorop=cv2.bitwise_xor(el,rc)
cv2.imshow("xor",xorop)
cv2.waitKey(0)
rop=cv2.bitwise_not(el)
cv2.imshow("xor",rop)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#filter 
import cv2
import numpy as np
image=cv2.imread("2.jpg")
cv2.imshow("image",image)
kernel=np.ones((7,7),np.float32)/49
blur=cv2.filter2D(image,-1,kernel)
cv2.imshow("blur",blur)
cv2.waitKey(0)
g=cv2.bilateralFilter(image,9,75,75)
cv2.imshow("gblur",g)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#sharpening
import cv2
import numpy as np
image=cv2.imread("2.jpg")
print(image.shape)
cv2.imshow("s",image)
kernel=np.array([[-1,-1,-1],[-1,10,-1],[-1,-1,-1]])
sharp=cv2.filter2D(image,-1,kernel)
cv2.imshow("sharp",sharp)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (356L, 640L, 3L)

# %%
#denoising
import cv2
import numpy as np
image=cv2.imread("1.jpg")
dst=cv2.fastNlMeansDenoisingColored(image, None, 60, 60, 7, 21)
cv2.imshow("dst",dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#thresholding
import cv2
import numpy as np
image=cv2.imread("2.jpg",0)
arjun,thresh1=cv2.threshold(image,10,255,cv2.THRESH_TOZERO)
cv2.imshow('image',thresh1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#erosion and dilation
import cv2
import numpy as np
image=cv2.imread("2.jpg",0)
k=np.ones((5,5),np.uint8)
erosion=cv2.erode(image,k,iterations=1)
cv2.imshow("erosion",erosion)
dilation=cv2.dilate(image,k,iterations=1)
cv2.imshow("d",dilation)
opening=cv2.morphologyEx(image,cv2.MORPH_CLOSE,k)
cv2.imshow("o",opening)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#sobel filter
import cv2
import numpy as np
image=cv2.imread("2.jpg",0)
h,w=image.shape
x=cv2.Sobel(image,cv2.CV_64F,0,1,ksize=5)
y=cv2.Sobel(image,cv2.CV_64F,1,0,ksize=5)
z=cv2.bitwise_or(x,y)
cv2.imshow("z",z)
canny=cv2.Canny(image,20,170)
cv2.imshow("canny",canny)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#live sketch
import cv2
import numpy as np
def sketch(image):
    imggray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    imgb=cv2.GaussianBlur(imggray,(5,5),0)
    canny=cv2.Canny(imgb,10,40)
    ret,y=cv2.threshold(canny,70,255,cv2.THRESH_BINARY_INV)
    return y

cap=cv2.VideoCapture(0)
while True:
    ret,frame=cap.read()
    cv2.imshow("live",sketch(frame))
    if cv2.waitKey(1)==13:
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
#draw contour
import cv2
import numpy as np
image=cv2.imread("c.webp")
edged=cv2.Canny(image,30,200)
cv2.imshow("edged",edged)
cv2.waitKey(0)
c,h=cv2.findContours(edged,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
print(str(len(c)))
cv2.imshow("c",edged)
cv2.drawContours(image,c,-1,(0,255,0),3)
cv2.imshow("ccc",image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 68

# %%
#sorting contour
sortedc=sorted(c,key=cv2.contourArea,reverse=False)
for i in sortedc:
    cv2.drawContours(image,[i],-1,(255,0,0),3)
    cv2.waitKey(0)
    cv2.imshow("oy",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#find moment through contour
import cv2
import numpy as np
 
img = cv2.imread('1.jpg',0)
ret,thresh = cv2.threshold(img,127,255,0)
contours,hierarchy = cv2.findContours(thresh, 1, 2)
 
cnt = contours[0]
M = cv2.moments(cnt)

M
# Out:
# {'m00': 5.0,
#  'm10': 4097.0,
#  'm01': 3830.5,
#  'm20': 3357087.833333333,
#  'm11': 3138713.9166666665,
#  'm02': 2934547.6666666665,
#  'm30': 2750807659.5,
#  'm21': 2571868621.75,
#  'm12': 2404571754.0833335,
#  'm03': 2248159444.25,
#  'mu20': 6.033333332743496,
#  'mu11': 2.2166666663251817,
#  'mu02': 1.6166666662320495,
#  'mu30': 1.4400010108947754,
#  'mu21': -0.039999401895329356,
#  'mu12': -0.35999924968950836,
#  'mu03': -0.23999929428100586,
#  'nu20': 0.24133333330973988,
#  'nu11': 0.08866666665300729,
#  'nu02': 0.06466666664928199,
#  'nu30': 0.025759521184233067,
#  'nu21': -0.000715531053578323,
#  'nu12': -0.006439862353237287,
#  'nu03': -0.004293237892514445}

# %%
import cv2
import numpy as np

# Function we'll use to display contour area
image=np.zeros((1024,1024,3),np.uint8)
img=cv2.circle(image,(255,255),50,(255,255,255),5)
cv2.imshow("img",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.rectangle(img,(350,350),(500,500),(255,255,255),5)
cv2.rectangle(img,(600,600),(700,700),(255,255,255),5)
cv2.imshow("rc",img)
cv2.waitKey(0)
edged=cv2.Canny(img,30,200)
contours,h=cv2.findContours(edged,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
j=0
for i in contours:
    j=j+1
print("no of contours:",j)

def get_contour_areas(contours):
    # returns the areas of all contours as list
    all_areas = []
    for cnt in contours:
        area = cv2.contourArea(cnt)
        all_areas.append(area)
    return all_areas

# Load our image

orginal_image = img

# Let's print the areas of the contours before sorting
print ("Contor Areas before sorting",) 
print (get_contour_areas(contours))

# Sort contours large to small
sorted_contours = sorted(contours, key=cv2.contourArea, reverse=True)
#print(sorted_contours)
#sorted_contours = sorted(contours, key=cv2.contourArea, reverse=True)[:3]

print ("Contor Areas after sorting",) 
print (get_contour_areas(sorted_contours))

# Iterate over our contours and draw one at a time
for c in sorted_contours:
    cv2.drawContours(orginal_image, [c], -1, (255,0,0), 3)
    cv2.waitKey(0)
    cv2.imshow('Contours by area', orginal_image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ('no of contours:', 3)
# ('Contor Areas before sorting',)
# [11426.0, 24626.0, 9009.0]
# ('Contor Areas after sorting',)
# [24626.0, 11426.0, 9009.0]

# %%
#shape sorting According to Area
import cv2
import numpy as np

# Functions we'll use for sorting by position

def x_cord_contour(contours):
    #Returns the X cordinate for the contour centroid
    if cv2.contourArea(contours) > 10:
        M = cv2.moments(contours)
        return (int(M['m10']/M['m00']))
    else:
        pass

    
def label_contour_center(image, c):
    # Places a red circle on the centers of contours
    M = cv2.moments(c)
    cx = int(M['m10'] / M['m00'])
    cy = int(M['m01'] / M['m00'])
 
    # Draw the countour number on the image
    cv2.circle(image,(cx,cy), 10, (255,255,255), -1)
    return image


# Load our image
image = edged
orginal_image = image.copy()


# Computer Center of Mass or centroids and draw them on our image
for (i, c) in enumerate(contours):
    orig = label_contour_center(edged, c)
 
cv2.imshow("4 - Contour Centers ", edged)
cv2.waitKey(0)

# Sort by left to right using our x_cord_contour function
contours_left_to_right = sorted(contours, key = x_cord_contour, reverse = False)


# Labeling Contours left to right
for (i,c)  in enumerate(contours_left_to_right):
    cv2.drawContours(orginal_image, [c], -1, (0,0,255), 3)  
    M = cv2.moments(c)
    cx = int(M['m10'] / M['m00'])
    cy = int(M['m01'] / M['m00'])
    cv2.putText(orginal_image, str(i+1), (cx, cy), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    cv2.imshow('6 - Left to Right Contour', orginal_image)
    cv2.waitKey(0)
    (x, y, w, h) = cv2.boundingRect(c)  
    
    # Let's now crop each contour and save these images
    cropped_contour = orginal_image[y:y + h, x:x + w]
    image_name = "output_shape_number_" + str(i+1) + ".jpg"
    print (image_name)
    
    cv2.imwrite(image_name, cropped_contour)
    
cv2.destroyAllWindows()
# Out:
# output_shape_number_1.jpg
# output_shape_number_2.jpg
# output_shape_number_3.jpg

# %%
#shape matching
import cv2
import numpy as np
temp1=cv2.imread("4star.jpg")
temp = cv2.cvtColor(temp1, cv2.COLOR_BGR2GRAY)
cv2.imshow("temp",temp)
cv2.waitKey(0)
ta=cv2.imread("someshapes.jpg")
target = cv2.cvtColor(ta, cv2.COLOR_BGR2GRAY)
cv2.imshow("temp",target)
cv2.waitKey(0)
cv2.destroyAllWindows()
ret,temp1=cv2.threshold(temp,127,255,0)
ret,temp2=cv2.threshold(target,127,255,0)
c,h=cv2.findContours(temp1,cv2.RETR_CCOMP,cv2.CHAIN_APPROX_NONE)
# print(len(c))
sortedc=sorted(c,key=cv2.contourArea,reverse=False)
tempc=c[0]
# print(tempc)
c1,h=cv2.findContours(temp2,cv2.RETR_CCOMP,cv2.CHAIN_APPROX_NONE)
print("target",len(c1))
for x in c1:
    match=cv2.matchShapes(tempc,x,1,0.0)
    print(match)
    if match<0.01:
        closestc=x
        print ("found")
        
    else:
        print("no")
final=cv2.drawContours(target,closestc,-1,(100,100,200),10)
cv2.imshow("output",final)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ('target', 6)
# 0.0179982087958
# no
# 0.233008765039
# no
# 0.0322391355273
# no
# 0.112469017733
# no
# 0.154278847408
# no
# 4.89829239256e-05
# found

# %%
#shape recognition
import cv2
import numpy as np
image=cv2.imread("shapestomatch.jpg")
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
r,thresh=cv2.threshold(gray,200,255,0)
cv2.imshow("threshold",thresh)
cv2.waitKey()
cv2.destroyAllWindows()
c,h=cv2.findContours(thresh.copy(),cv2.RETR_LIST,cv2.CHAIN_APPROX_NONE)
for i in c:
    ap=cv2.approxPolyDP(i,0.01*cv2.arcLength(i,True),True)
    print(len(ap))
    if len(ap)==3:
        name="Triangle"
        cv2.drawContours(image,i,0,(0,255,0),-1)
        
        m=cv2.moments(i)
        cx=int(m['m10']/m['m00'])
        cy=int(m['m01']/m['m00'])
        cv2.putText(image,name,(cx-50,cy),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),1)
    elif len(ap) == 4:
        x,y,w,h=cv2.boundingRect(i)
        m=cv2.moments(i)
        cx=int(m['m10']/m['m00'])
        cy=int(m['m01']/m['m00'])
        
        if abs(w-h)<=3:
            name="square"
            cv2.drawContours(image,i,0,(0,0,255),-1)
            cv2.putText(image,name,(cx-50,cy),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),1)
        else:
            name="rectangle"
            cv2.drawContours(image,i,0,(0,0,255),-1)
            cv2.putText(image,name,(cx-50,cy),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),1)
    elif len(ap)==10:
        name="Star"
        cv2.drawContours(image,i,0,(0,255,0),-1)
        
        m=cv2.moments(i)
        cx=int(m['m10']/m['m00'])
        cy=int(m['m01']/m['m00'])
        cv2.putText(image,name,(cx-50,cy),cv2.FONT_HERSHEY_SIMPLEX,1,(255,255,255),3)
    elif len(ap)>=12:
        name="CIRCLE"
        cv2.drawContours(image,i,0,(0,255,0),-1)
        
        m=cv2.moments(i)
        cx=int(m['m10']/m['m00'])
        cy=int(m['m01']/m['m00'])
        cv2.putText(image,name,(cx-50,cy),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),1)
cv2.imshow("image",image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# 10
# 5
# 8
# 4

# %%
import cv2
import numpy as np
image = cv2.imread('soduku.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray, 100, 255, apertureSize = 3)
lines = cv2.HoughLinesP(edges, 1, np.pi / 180, 200, 5, 10)
o=(len(lines))
print(lines)
i=0
while(i<=o):
    for x1, y1, x2, y2 in lines[i]:
            cv2.line(image, (x1, y1), (x2, y2),(0, 255, 0), 3)
    i=i+1
cv2.imshow('Probabilistic Hough Lines', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[[332 562 370 550]]
#
#  [[127 140 134 163]]
#
#  [[568  32 580  53]]
#
#  [[ 38 148  43 169]]
#
#  [[122 468 125 481]]
#
#  [[284 399 290 416]]
#
#  [[196 353 208 391]]
#
#  [[ 82 321  85 334]]
#
#  [[627 336 638 333]]
#
#  [[385 541 408 534]]
#
#  [[274 446 296 440]]
#
#  [[472 384 483 381]]
#
#  [[242 285 254 319]]
#
#  [[158 474 164 496]]
#
#  [[ 31 129  36 150]]
#
#  [[438   6 444  18]]
#
#  [[ 73 280  77 294]]
#
#  [[738 326 767 376]]
#
#  [[321 302 348 294]]
#
#  [[489 507 521 497]]
#
#  [[125 140 130 157]]
#
#  [[323 243 335 240]]
#
#  [[702 375 727 367]]
#
#  [[103 391 111 422]]
#
#  [[317 433 328 430]]
#
#  [[327 428 338 425]]
#
#  [[188 141 198 168]]
#
#  [[112 304 128 361]]
#
#  [[511 372 522 369]]
#
#  [[453 522 481 513]]
#
#  [[468 331 474 344]]
#
#  [[ 73 287  78 308]]
#
#  [[589 178 596 190]]
#
#  [[649 171 673 214]]
#
#  [[171 410 186 406]]
#
#  [[ 98 446 101 459]]
#
#  [[397 222 440 210]]
#
#  [[464  59 471  72]]
#
#  [[401 281 415 277]]
#
#  [[664 388 689 380]]
#
# ...

# %%
#draw Hough lines
import cv2
import numpy as np

image = cv2.imread('soduku.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray, 100, 170, apertureSize = 3)
cv2.imshow('Hough Lines', edges)
cv2.waitKey(0)
cv2.destroyAllWindows()
lines = cv2.HoughLines(edges, 1, np.pi / 180, 240)
o=(len(lines))
i=0
while(i<o):
    
    for rho, theta in lines[i]:
        a = np.cos(theta)
        b = np.sin(theta)
        x0 = a * rho
        y0 = b * rho
        x1 = int(x0 + 1000 * (-b))
        y1 = int(y0 + 1000 * (a))
        x2 = int(x0 - 1000 * (-b))
        y2 = int(y0 - 1000 * (a))
        cv2.line(image, (x1, y1), (x2, y2), (255, 0, 0), 2)
        i=i+1

cv2.imshow('Hough Lines', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#circle detection
import cv2
import numpy as np
import cv2 as cv



image = cv2.imread('bottlecaps.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('gray', gray)
cv2.waitKey(0)
cv2.destroyAllWindows()
#blur = cv2.medianBlur(gray, 5)
edged=cv2.Canny(blur,30,200)
cv2.imshow('edged', edged)
cv2.waitKey(0)
cv2.destroyAllWindows()


circles = cv2.HoughCircles(edged, cv2.HOUGH_GRADIENT, 1, 10)

circles = np.uint16(np.around(circles))
print(len(circles))
#for i in circles[0]:
 #   y=i[1]
  #  r=i[2]
   # cv2.circle(image,(x,y),r, (255, 0, 0), 2)
    #cv2.circle(image, (i[0], i[1]), 2, (0, 255, 0), 5)
dst=cv2.fastNlMeansDenoisingColored(image, None, 60, 60, 7, 21)
cv2.imshow('detected circles', dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1

# %%
#blob detection
import cv2
import numpy as np
image=cv2.imread("Sunflowers.jpg",cv2.IMREAD_GRAYSCALE)
detector=cv2.SimpleBlobDetector()
kp=detector.detect(image)
blank=np.zeros((1,1))
blobs=cv2.drawKeypoints(image,kp,blank,(0,255,255),cv2.DRAW_MATCHES_FLAGS_DEFAULT)
cv2.imshow("b",blobs)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread("blobs.jpg", 0)
cv2.imshow('Original Image',image)
cv2.waitKey(0)

# Intialize the detector using the default parameters
detector = cv2.SimpleBlobDetector()
 
# Detect blobs
keypoints = detector.detect(image)
 
# Draw blobs on our image as red circles
blank = np.zeros((1,1)) 
blobs = cv2.drawKeypoints(image, keypoints, blank, (0,0,255),
                                      cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

number_of_blobs = len(keypoints)
text = "Total Number of Blobs: " + str(len(keypoints))
cv2.putText(blobs, text, (20, 550), cv2.FONT_HERSHEY_SIMPLEX, 1, (100, 0, 255), 2)

# Display image with blob keypoints
cv2.imshow("Blobs using default parameters", blobs)
cv2.waitKey(0)


# Set our filtering parameters
# Initialize parameter settiing using cv2.SimpleBlobDetector
params = cv2.SimpleBlobDetector_Params()

# Set Area filtering parameters
params.filterByArea = True
params.minArea = 100

# Set Circularity filtering parameters
params.filterByCircularity = True 
params.minCircularity = 0.9

# Set Convexity filtering parameters
params.filterByConvexity = False
params.minConvexity = 0.2
    
# Set inertia filtering parameters
params.filterByInertia = True
params.minInertiaRatio = 0.01

# Create a detector with the parameters
detector = cv2.SimpleBlobDetector(params)
    
keypoints = detector.detect(image)

blank = np.zeros((1,1)) 
blobs = cv2.drawKeypoints(image, keypoints, blank, (0,255,0),
                                      cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

number_of_blobs = len(keypoints)
text = "Number of Circular Blobs: " + str(len(keypoints))
cv2.putText(blobs, text, (20, 550), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 100, 255), 2)

cv2.imshow("Filtering Circular Blobs Only", blobs)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# templet matching
import cv2
import numpy as np

image = cv2.imread('WaldoBeach.jpg')
cv2.imshow('Where is Waldo?', image)
cv2.waitKey(0)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

template = cv2.imread('waldo.jpg',0)

result = cv2.matchTemplate(gray, template, cv2.TM_CCOEFF)
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

top_left = max_loc
bottom_right = (top_left[0] + 50, top_left[1] + 50)
cv2.rectangle(image, top_left, bottom_right, (0,0,255), 5)

cv2.imshow('Where is Waldo?', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#find corners
import cv2
import numpy as np

image = cv2.imread('chess.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)

harris_corners = cv2.cornerHarris(gray, 3, 3, 0.05)
cv2.imshow('Harris Corners',harris_corners)
cv2.waitKey(0)
cv2.destroyAllWindows()
kernel = np.ones((7,7),np.uint8)
harris_corners = cv2.dilate(harris_corners, kernel, iterations = 2)

cv2.imshow('Harris Corners',harris_corners)
cv2.waitKey(0)
cv2.destroyAllWindows()
image[harris_corners > 0.025 * harris_corners.max() ] = [255, 127, 127]

cv2.imshow('Harris Corners', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# HOG descriptor
import numpy as np
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('elephant.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2.imshow('Input Image', image)
cv2.waitKey(0)

cell_size = (8, 8) 

block_size = (2, 2) 

nbins = 9
hog = cv2.HOGDescriptor(_winSize=(gray.shape[1] // cell_size[1] * cell_size[1],
                                  gray.shape[0] // cell_size[0] * cell_size[0]),
                        _blockSize=(block_size[1] * cell_size[1],
                                    block_size[0] * cell_size[0]),
                        _blockStride=(cell_size[1], cell_size[0]),
                        _cellSize=(cell_size[1], cell_size[0]),
                        _nbins=nbins)

n_cells = (gray.shape[0] // cell_size[0], gray.shape[1] // cell_size[1])

hog_feats = hog.compute(gray).reshape(n_cells[1] - block_size[1] + 1,
                        n_cells[0] - block_size[0] + 1,
                        block_size[0], block_size[1], nbins).transpose((1, 0, 2, 3, 4))  

gradients = np.zeros((n_cells[0], n_cells[1], nbins))

cell_count = np.full((n_cells[0], n_cells[1], 1), 0, dtype=int)


for off_y in range(block_size[0]):
    for off_x in range(block_size[1]):
        gradients[off_y:n_cells[0] - block_size[0] + off_y + 1,
                  off_x:n_cells[1] - block_size[1] + off_x + 1] += \
            hog_feats[:, :, off_y, off_x, :]
        cell_count[off_y:n_cells[0] - block_size[0] + off_y + 1,
                   off_x:n_cells[1] - block_size[1] + off_x + 1] += 1

gradients /= cell_count

color_bins = 5
plt.pcolor(gradients[:, :, color_bins])
plt.gca().invert_yaxis()
plt.gca().set_aspect('equal', adjustable='box')
plt.colorbar()
plt.show()
cv2.destroyAllWindows()

# %%
#face classifier
import numpy as np
import cv2

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

image = cv2.imread('Trump.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

faces = face_classifier.detectMultiScale(gray, 1.3, 5)

if faces is ():
    print("No faces found")
print(faces)
for (x,y,w,h) in faces:
    cv2.rectangle(image, (x,y), (x+w,y+h), (127,0,255), 2)
    print(x,y,w,h)
    cv2.imshow('Face Detection', image)
    cv2.waitKey(0)
    
cv2.destroyAllWindows()
# Out:
# [[ 53  70 215 215]]
# (53, 70, 215, 215)

# %%
# eye classifier
import numpy as np
import cv2
myclassifier=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eyeclassifier=cv2.CascadeClassifier('haarcascade_eye.xml')
image=cv2.imread("Trump.jpg")
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
faces=myclassifier.detectMultiScale(gray,1.1,10)
if faces is():
    print("No Face")
for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(127,0,0),2)
    #cv2.imshow("face",image)
    cv2.waitKey(0)
    grayeye = gray[y:y+h, x:x+w]
    coloreye = image[y:y+h, x:x+w]
    eye=eyeclassifier.detectMultiScale(grayeye,1.5,2)
    for (ex,ey,ew,eh) in eye:
        cv2.rectangle(coloreye,(ex,ey),(ex+ew,ey+eh),(255,255,0),1)
        cv2.imshow('img',image)
        cv2.waitKey(0)
    
cv2.destroyAllWindows()

# %%
#live face Classifier
import cv2
import numpy as np

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_classifier = cv2.CascadeClassifier('haarcascade_eye.xml')

def face_detector(img, size=0.5):
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img
    
    for (x,y,w,h) in faces:
        x = x - 50
        w = w + 50
        y = y - 50
        h = h + 50
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_classifier.detectMultiScale(roi_gray)
        
        for (ex,ey,ew,eh) in eyes:
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,0,255),2) 
            
    roi_color = cv2.flip(roi_color,1)
    return roi_color

cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()
    cv2.imshow('Our Face Extractor', face_detector(frame))
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
#blob detector
import cv2
import numpy as np;
 

image = cv2.imread("Sunflowers.jpg")

detector = cv2.SimpleBlobDetector()
keypoints = detector.detect(image)

blank = np.zeros((1,1)) 
blobs = cv2.drawKeypoints(image, keypoints, blank, (0,255,255),
                                      cv2.DRAW_MATCHES_FLAGS_DEFAULT)
 

cv2.imshow("Blobs", blobs)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# flipping image

# import the OpenCV package
import cv2

# load the image with imread()
imageSource = '1.jpg'
img = cv2.imread(imageSource)

# copy image to display all 4 variations
horizontal_img = img.copy()
vertical_img = img.copy()
both_img = img.copy()

# flip img horizontally, vertically,
# and both axes with flip()
horizontal_img = cv2.flip( img, 0 )
vertical_img = cv2.flip( img, 1 )
both_img = cv2.flip( img, -1 )

# display the images on screen with imshow()
cv2.imshow( "Original", img )
cv2.waitKey(0)
cv2.imshow( "Horizontal flip", horizontal_img )
cv2.waitKey(0)
cv2.imshow( "Vertical flip", vertical_img )
cv2.waitKey(0)
cv2.imshow( "Both flip", both_img )


# wait time in milliseconds
# this is required to show the image
# 0 = wait indefinitely
cv2.waitKey(0)

# close the windows
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
cap=cv2.VideoCapture()
cap.release()
cv2.destroyAllWindows()
